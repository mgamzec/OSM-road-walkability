# %%
import osmnx as ox

# %%
road1 = ox.graph_from_place("Antalya, Turkiye")
ox.plot_graph(road1)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
road3 = ox.graph_from_polygon()

# %%
road2 = ox.graph_from_point(( 36.899708152002844, 30.69587423136062), dist = 4000, network_type="drive")
# network_type:drive, drive_service,walk,bike,all, all_private
ox.plot_graph(road2)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
import geopandas as gpd

# %%
polygon = gpd.read_file(r"C:\Users\merve\Desktop\OSM-GDAL\Data\pol_ant_shp\POLYGON.shp")

# %%
polygon.plot()
# Out:
# <Axes: >

# %%
polygon.columns
# Out:
# Index(['geometry'], dtype='object')

# %%
antalya = polygon["geometry"].iloc[0]
antalya
# Out:
# <POLYGON ((30.696 36.923, 30.693 36.922, 30.69 36.922, 30.688 36.922, 30.685...>

# %%
road3 = ox.graph_from_polygon(antalya, network_type="drive")
ox.plot_graph(road3)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
file_path = r"C:\Users\merve\Desktop\OSM-GDAL\Data\pol_ant_shp\New_road\road3.shp"

ox.save_graph_shapefile(road3, file_path)
# Out:
# C:\Users\merve\AppData\Local\Temp\ipykernel_27176\3129667477.py:3: UserWarning: The `save_graph_shapefile` function is deprecated and will be removed in a future release. Instead, use the `save_graph_geopackage` function to save graphs as GeoPackage files for subsequent GIS analysis.
#   ox.save_graph_shapefile(road3, file_path)
# C:\Users\merve\anaconda3\envs\gdal\lib\site-packages\osmnx\io.py:117: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)
